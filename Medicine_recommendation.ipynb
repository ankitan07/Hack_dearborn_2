# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitan07/Hack_dearborn_2/blob/main/Medicine_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O medicine.csv "https://github.com/dhrupad17/CodeClause_Personalized_Medicine_Recommending_System/blob/main/medicine.csv"
# Out:
# --2023-10-21 22:20:13--  https://github.com/dhrupad17/CodeClause_Personalized_Medicine_Recommending_System/blob/main/medicine.csv
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4948 (4.8K) [text/plain]
# Saving to: ‘medicine.csv’
#
# medicine.csv        100%[===================>]   4.83K  --.-KB/s    in 0s
#
# 2023-10-21 22:20:13 (46.7 MB/s) - ‘medicine.csv’ saved [4948/4948]

# %%
import pandas as pd

# %%
df=pd.read_csv("medicine.csv")

# %%
df.tail()
# Out:
#       index                                          Drug_Name Reason  \
# 9715   9716                                T Muce Ointment 5gm  Wound
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...  Wound
# 9717   9718                               Wokadine M Onit 10gm  Wound
# 9718   9719                           Wound Fix Solution 100ml  Wound
# 9719   9720                              Wounsol Ointment 15gm  Wound
#
#                                             Description
# 9715                            used for treating warts
# 9716                      used to soften the skin cells
# 9717                                     used for scars
# 9718                                    used for wounds
# 9719  used to treat and remove raised warts (usually...
